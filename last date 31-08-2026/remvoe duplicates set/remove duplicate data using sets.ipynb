# %%
numbers = [10, 20, 30, 20, 40, 10, 50, 30, 60]

# %%
print("Original list:", numbers)
# Out:
# Original list: [10, 20, 30, 20, 40, 10, 50, 30, 60]

# %%
unique_numbers = set(numbers)
print("Set:", unique_numbers)
# Out:
# Set: {40, 10, 50, 20, 60, 30}

# %%
unique_list = list(unique_numbers)
print("Unique list:", unique_list)
# Out:
# Unique list: [40, 10, 50, 20, 60, 30]

# %%
print("Number of original elements:", len(numbers))
print("Number of unique elements:", len(unique_numbers))
# Out:
# Number of original elements: 9
# Number of unique elements: 6

# %%
students = [
    "Shivani",
    "Mithran",
    "Krithik",
    "Shivani",
    "Aaradhana",
    "Mithran",
    "Krithik"
]

# %%
print("Original students:", students)
# Out:
# Original students: ['Shivani', 'Mithran', 'Krithik', 'Shivani', 'Aaradhana', 'Mithran', 'Krithik']

# %%
unique_students = set(students)
print("Unique students:", unique_students)
# Out:
# Unique students: {'Mithran', 'Krithik', 'Aaradhana', 'Shivani'}

# %%
print("Total entries:", len(students))
print("Unique students:", len(unique_students))
# Out:
# Total entries: 7
# Unique students: 4
