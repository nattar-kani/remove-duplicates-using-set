# %%
name = 'kani'
age = 27
city = 'chennai'
college = 'AU'
curr_learning_topic = 'Python'
exp_years = 5
python_likes = True
expected_salary = 12_00_000

# %%
print(f"Name: {name} | Type: {type(name)}")
print(f"Age: {age} | Type: {type(age)}")
print(f"City: {city} | Type: {type(city)}")
print(f"College: {college} | Type: {type(college)}")
print(f"Current learning topic: {curr_learning_topic} | Type: {type(curr_learning_topic)}")
print(f"Years of experience: {exp_years} | Type: {type(exp_years)}")
print(f"Do I like Python? {python_likes} | Type: {type(python_likes)}")
print(f"Expected salary: {expected_salary} | Type: {type(expected_salary)}")
# Out:
# Name: kani | Type: <class 'str'>
# Age: 27 | Type: <class 'int'>
# City: chennai | Type: <class 'str'>
# College: AU | Type: <class 'str'>
# Current learning topic: Python | Type: <class 'str'>
# Years of experience: 5 | Type: <class 'int'>
# Do I like Python? True | Type: <class 'bool'>
# Expected salary: 1200000 | Type: <class 'int'>
